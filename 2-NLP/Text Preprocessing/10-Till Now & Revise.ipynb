# %% [markdown]
# ---
#
# ## 🔹 **Text Preprocessing - 2**
#
# 1. **Tokenization**
#    → Breaking text into individual words or tokens.
#
# 2. **Lowercasing the Words**
#    → Converting all text into lowercase for uniformity.
#
# 3. **Regular Expression (Regex)**
#    → Removing unwanted characters, symbols, or patterns from text.
#
# ---
#
# ## 🔹 **Text Preprocessing - 2**
#
# 1. **Stemming**
#    → Reducing words to their root form (e.g., *running* → *run*).
#
# 2. **Lemmatization**
#    → Converting words to their base dictionary form using linguistic rules.
#
# 3. **Stopwords Removal**
#    → Removing common words (like *the*, *is*, *in*) that do not contribute to meaning.
#
# ---
#
# ## 🔹 **Text Preprocessing - 2**
#
# 1. **One-Hot Encoding**
# Each word is represented by a binary vector with 1 at the index of that word.
#
#
# 2. **Bag of Words (BoW)**
# Counts the frequency of each word in the document.
#
# **Example:**
# | Word  | Frequency |
# |--------|------------|
# | cat    | 2          |
# | dog    | 1          |
# | apple  | 3          |
#
#
# 3. **TF-IDF (Term Frequency – Inverse Document Frequency)**
# Gives importance to words that are frequent in a document but rare across others.
#
# 4. **Word2Vec**
# Represents words as dense vectors based on their semantic meaning and context.
# 5. **AvgWord2Vec**
# Takes the average of all Word2Vec vectors in a sentence or document to form a single vector.
#
# ---
#
# ## 🔹 **ML or DL Algorithm - 4**
#
# After converting text to vectors, you can train models such as:
#
# | Category | Algorithms |
# |-----------|-------------|
# | 🧮 **Machine Learning** | Logistic Regression, Naive Bayes, SVM, Random Forest |
# | 🧠 **Deep Learning** | RNN, LSTM, GRU, Transformer, BERT |
#
# ---
#
# ## 🧩 **Text Preprocessing Pipeline**
#
# ```mermaid
# flowchart LR
#     A[📘 DataSet] --> B[🧩 Tokenization]
#     B --> C[🔡 Lowercasing]
#     C --> D[✨ Regex Cleaning]
#     D --> E[🌿 Stemming / Lemmatization]
#     E --> F[🚫 Stopwords Removal]
#     F --> G[🔢 Text to Vectors]
#     G --> H[🤖 ML / DL Algorithm]
